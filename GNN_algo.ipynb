# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# install libraries
# !pip install pykeen pandas networkx matplotlib

# %%
# %cd /content/drive/MyDrive/datos/GNN_job
# !python src/main.py
# Out:
# /content/drive/MyDrive/datos/GNN_job
#
# [1] Loading data...
#
# [2] Graph exploration...
# Nodes: 133369
# Edges: 398126
# Figure(640x480)
#
# [3] Train or load models...
#  Loading existing TransE
# [INFO] Loading model from models/TransE.pkl
#  Training ComplEx
# [INFO] Training ComplEx on cuda
# Training epochs on cuda:0:   0% 0/300 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0% 0.00/390 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0% 1.00/390 [00:00<01:00, 6.47batch/s]
# Training batches on cuda:0:   1% 4.00/390 [00:00<00:24, 15.6batch/s]
# Training batches on cuda:0:   2% 7.00/390 [00:00<00:20, 19.0batch/s]
# Training batches on cuda:0:   3% 10.0/390 [00:00<00:18, 20.8batch/s]
# Training batches on cuda:0:   3% 13.0/390 [00:00<00:16, 22.2batch/s]
# Training batches on cuda:0:   4% 16.0/390 [00:00<00:16, 23.1batch/s]
# Training batches on cuda:0:   5% 19.0/390 [00:00<00:15, 23.7batch/s]
# Training batches on cuda:0:   6% 22.0/390 [00:01<00:15, 24.1batch/s]
# ...
